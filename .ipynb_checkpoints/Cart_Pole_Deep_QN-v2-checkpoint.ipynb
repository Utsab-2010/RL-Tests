# %%
import gymnasium as gym
import pygame
from gymnasium.utils.play import play
# from gynasium.utils.play import pl
import torch
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib
import matplotlib.pyplot as plt
import random
# %matplotlib inline

matplotlib.rcParams['figure.facecolor'] = '#ffffff'

# %%
env = gym.make("CartPole-v1",render_mode="human")

# %%
class Q_Network(nn.Module):
    def __init__(self):
        super(Q_Network, self).__init__()
        self.network = nn.Sequential(nn.Linear(4,24),
                                     nn.Tanh(),
                                     nn.Linear(24,8),
                                     nn.Tanh(),
                                     nn.Linear(8,2))
    def forward(self,state):
            return self.network(state)

# %%
# @torch.no_grad()
def train(epochs,lr,model,rm_size,batch_size,max_steps,gamma,opt_func=torch.optim.Adam):

    max_epsilon = 1.0             # Exploration probability at start
    min_epsilon = 0.05
    decay_rate = 3e-4
    epsilon = max_epsilon
    env = gym.make("CartPole-v1",render_mode="human")
    optimizer = opt_func(model.parameters(),lr)
    replay_memory = list()
    model_old = model
    # replay_memory = replay_memory
    history=[]
    for epoch in range(epochs):
        state , info = env.reset()
        state = torch.from_numpy(state)

        total_reward = 0
        for step in range(max_steps):
            
            #Sampling Phase
            exp_exp_tradeoff = random.uniform(0, 1)
            if exp_exp_tradeoff > epsilon:
                action = torch.argmax(model.forward(state)).item()
            else:
                action = env.action_space.sample()

            new_state, reward, done,truncated, info= env.step(action)
            new_state = torch.from_numpy(new_state)
            memory = [state,action,reward,new_state]
            total_reward += reward
            
            if len(replay_memory) == rm_size:
                replay_memory.pop(0)
            replay_memory.append(memory)
            if done or truncated:
                print(epoch,":",total_reward)
                break
            
            #Training Phase
            batch = random.sample(replay_memory,batch_size) if len(replay_memory)>batch_size else []
            loss=0
            for element in batch:
                
                rand_state,rand_action,rand_reward,target_state = element
                target_Q = rand_reward + gamma*torch.max(model_old.forward(target_state)).item()
                trial_Q = model.forward(rand_state)[rand_action]
                
                model_old = model   #saving the model's old parameters in an target model variable
                loss += (target_Q-trial_Q)**2

            #updating the current model
            if len(batch):
                loss /= 2*batch_size
                loss.backward()
                optimizer.step()
                optimizer.zero_grad()
                
            #State-Change
            state = new_state

        history.append(total_reward)
        epsilon = min_epsilon + (max_epsilon - min_epsilon)*np.exp(-decay_rate*epoch) 
        # epsilon = 0.01
        
    env.close()
    return history

# %%
model = Q_Network()
model
# Out:
# Q_Network(
#   (network): Sequential(
#     (0): Linear(in_features=4, out_features=24, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=24, out_features=8, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=8, out_features=2, bias=True)
#   )
# )

# %%
epochs=500
# epsilon=1.0
# max_epsilon = 1.0             # Exploration probability at start
# min_epsilon = 0.2 
max_steps=300
gamma=0.7
lr = 1e-4
rm_size=60
batch_size=20

# %%
history=[]

# %%
history+=train(epochs,lr,model,rm_size,batch_size,max_steps,gamma)
# Out:
# 0 : 58.0
# 1 : 18.0
# 2 : 25.0
# 3 : 16.0
# 4 : 16.0
# 5 : 15.0
# 6 : 20.0
# 7 : 38.0
# 8 : 20.0
# 9 : 24.0
# 10 : 31.0
# 11 : 13.0
# 12 : 23.0
# 13 : 24.0
# 14 : 22.0
# 15 : 32.0
# 16 : 15.0
# 17 : 17.0
# 18 : 33.0
# 19 : 27.0
# 20 : 14.0
# 21 : 12.0
# 22 : 29.0
# 23 : 11.0
# 24 : 35.0
# 25 : 13.0
# 26 : 12.0
# 27 : 21.0
# 28 : 12.0
# 29 : 37.0
# 30 : 12.0
# 31 : 18.0
# 32 : 14.0
# 33 : 33.0
# 34 : 14.0
# 35 : 28.0
# 36 : 27.0
# 37 : 13.0
# 38 : 13.0
# 39 : 16.0
# 40 : 31.0
# 41 : 63.0
# 42 : 13.0
# 43 : 14.0
# 44 : 30.0
# 45 : 11.0
# 46 : 12.0
# 47 : 15.0
# 48 : 24.0
# 49 : 15.0
# 50 : 16.0
# 51 : 20.0
# 52 : 49.0
# 53 : 13.0
# 54 : 18.0
# 55 : 19.0
# 56 : 30.0
# 57 : 43.0
# 58 : 24.0
# 59 : 17.0
# 60 : 14.0
# 61 : 47.0
# 62 : 26.0
# 63 : 17.0
# 64 : 49.0
# 65 : 20.0
# 66 : 20.0
# 67 : 14.0
# 68 : 25.0
# 69 : 16.0
# 70 : 28.0
# 71 : 19.0
# 72 : 9.0
# 73 : 48.0
# 74 : 58.0
# 75 : 38.0
# 76 : 28.0
# 77 : 13.0
# 78 : 13.0
# 79 : 18.0
# 80 : 9.0
# 81 : 14.0
# 82 : 23.0
# 83 : 17.0
# 84 : 19.0
# 85 : 13.0
# 86 : 10.0
# 87 : 12.0
# 88 : 11.0
# 89 : 29.0
# 90 : 39.0
# 91 : 25.0
# 92 : 34.0
# 93 : 21.0
# 94 : 31.0
# 95 : 17.0
# 96 : 14.0
# 97 : 46.0
# 98 : 15.0
# 99 : 10.0
# 100 : 13.0
# 101 : 12.0
# 102 : 19.0
# 103 : 15.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 history+=train(epochs,lr,model,rm_size,batch_size,max_steps,gamma)
#
# Cell In[108], line 28, in train(epochs, lr, model, rm_size, batch_size, max_steps, gamma, opt_func)
#      25 else:
#      26     action = env.action_space.sample()
# ---> 28 new_state, reward, done,truncated, info= env.step(action)
#      29 new_state = torch.from_numpy(new_state)
#      30 memory = [state,action,reward,new_state]
#
# File D:\miniconda\envs\IRL_env\lib\site-packages\gymnasium\wrappers\common.py:125, in TimeLimit.step(self, action)
#     112 def step(
#     113     self, action: ActType
#     114 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     115     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     116
#     117     Args:
#    (...)
#     123
#     124     """
# --> 125     observation, reward, terminated, truncated, info = self.env.step(action)
#     126     self._elapsed_steps += 1
#     128     if self._elapsed_steps >= self._max_episode_steps:
#
# File D:\miniconda\envs\IRL_env\lib\site-packages\gymnasium\wrappers\common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File D:\miniconda\envs\IRL_env\lib\site-packages\gymnasium\core.py:322, in Wrapper.step(self, action)
#     318 def step(
#     319     self, action: WrapperActType
#     320 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     321     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 322     return self.env.step(action)
#
# File D:\miniconda\envs\IRL_env\lib\site-packages\gymnasium\wrappers\common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File D:\miniconda\envs\IRL_env\lib\site-packages\gymnasium\envs\classic_control\cartpole.py:223, in CartPoleEnv.step(self, action)
#     220     reward = -1.0 if self._sutton_barto_reward else 0.0
#     222 if self.render_mode == "human":
# --> 223     self.render()
#     225 # truncation=False as the time limit is handled by the `TimeLimit` wrapper added during `make`
#     226 return np.array(self.state, dtype=np.float32), reward, terminated, False, {}
#
# File D:\miniconda\envs\IRL_env\lib\site-packages\gymnasium\envs\classic_control\cartpole.py:337, in CartPoleEnv.render(self)
#     335 if self.render_mode == "human":
#     336     pygame.event.pump()
# --> 337     self.clock.tick(self.metadata["render_fps"])
#     338     pygame.display.flip()
#     340 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(14, 6))
plt.plot(history, marker='o', linestyle='-', color='b')

window_size=10
smoothed_data = np.convolve(history, np.ones(window_size)/window_size, mode='valid')
smoothed_indices = range(window_size - 1, len(history))
plt.plot(smoothed_indices, smoothed_data, marker='', linestyle='-', color='r', label='Smoothed Data')

plt.title("Model Training")
plt.xlabel("Epochs")
plt.ylabel("Avg Score")
# plt.legend()
plt.grid(True)
plt.show()

# %%
def test(model,episodes):
    env = gym.make("CartPole-v1",render_mode="human")
    state,info = env.reset()
    state = torch.from_numpy(state)
    total_reward=0
    for ep in range(episodes):
       
        action = torch.argmax(model.forward(state)).item()
        new_state, reward, done,truncated, info= env.step(action)
        total_reward+=reward
        
        if done or truncated:
            print(total_reward)
            break
        state = torch.from_numpy(new_state)    
    env.close()

# %%
for i in range(20):
    print(i)
    test(model,100)
# Out:
# 0
# 16.0
# 1
# 16.0
# 2
# 43.0
# 3
# 22.0
# 4
# 53.0
# 5
# 18.0
# 6
# 19.0
# 7
# 19.0
# 8
# 21.0
# 9
# 58.0
# 10
# 41.0
# 11
# 23.0
# 12
# 30.0
# 13
# 23.0
# 14
# 29.0
# 15
# 33.0
# 16
# 39.0
# 17
# 16.0
# 18
# 42.0
# 19
# 21.0
